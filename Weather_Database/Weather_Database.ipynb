# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Create a new set of 2,000 random latitudes & longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Perform API Call & retrieve Lat, Long, Max temp, % humid, % cloudiness, wind speed, weather descrip
import requests
from config import weather_api_key
import time
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List to hold cities
city_data = []
# Print Beginning Data Retrieval
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_description = city_weather["weather"][0]["description"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | kununurra
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | teahupoo
# Processing Record 13 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | onega
# Processing Record 16 of Set 1 | dunedin
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | ponta delgada
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | buala
# Processing Record 24 of Set 1 | srednekolymsk
# Processing Record 25 of Set 1 | bandarbeyla
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | florence
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | bimbo
# Processing Record 30 of Set 1 | lasa
# Processing Record 31 of Set 1 | saint-denis
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | hope
# Processing Record 34 of Set 1 | evensk
# Processing Record 35 of Set 1 | yaan
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | inhambane
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | gazanjyk
# Processing Record 40 of Set 1 | semirom
# Processing Record 41 of Set 1 | college
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | saint-pierre
# Processing Record 45 of Set 1 | hovd
# Processing Record 46 of Set 1 | virginia beach
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | bilma
# Processing Record 49 of Set 1 | kuli
# Processing Record 50 of Set 1 | gat
# Processing Record 1 of Set 2 | batemans bay
# Processing Record 2 of Set 2 | bathurst
# Processing Record 3 of Set 2 | baherden
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | posse
# Processing Record 8 of Set 2 | meadow lake
# Processing Record 9 of Set 2 | penzance
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | pochutla
# Processing Record 12 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 2 | maniitsoq
# Processing Record 14 of Set 2 | riachao das neves
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | arvika
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | olga
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | ust-tsilma
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | keffi
# Processing Record 31 of Set 2 | orzhytsya
# Processing Record 32 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 33 of Set 2 | porto santo
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | sainte-marie
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | oranjemund
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | dhidhdhoo
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | ziro
# Processing Record 42 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 2 | touros
# Processing Record 44 of Set 2 | izyum
# Processing Record 45 of Set 2 | manakara
# Processing Record 46 of Set 2 | khani
# Processing Record 47 of Set 2 | ambilobe
# Processing Record 48 of Set 2 | council bluffs
# Processing Record 49 of Set 2 | guanica
# Processing Record 50 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 3 | najran
# Processing Record 2 of Set 3 | port-gentil
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | qufu
# Processing Record 5 of Set 3 | havoysund
# Processing Record 6 of Set 3 | san pedro
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | talnakh
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | aklavik
# Processing Record 11 of Set 3 | paamiut
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 3 | miranda
# Processing Record 16 of Set 3 | lavrentiya
# Processing Record 17 of Set 3 | yerky
# Processing Record 18 of Set 3 | toora-khem
# Processing Record 19 of Set 3 | kahului
# Processing Record 20 of Set 3 | san cristobal
# Processing Record 21 of Set 3 | carauari
# Processing Record 22 of Set 3 | clarence town
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | pitimbu
# Processing Record 25 of Set 3 | terre haute
# Processing Record 26 of Set 3 | salinopolis
# Processing Record 27 of Set 3 | camacupa
# Processing Record 28 of Set 3 | marsh harbour
# Processing Record 29 of Set 3 | flinders
# Processing Record 30 of Set 3 | mizdah
# Processing Record 31 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | zeya
# Processing Record 34 of Set 3 | kirakira
# Processing Record 35 of Set 3 | dallas
# Processing Record 36 of Set 3 | ahipara
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | ilhabela
# Processing Record 40 of Set 3 | avera
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | haines junction
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | miandrivazo
# Processing Record 45 of Set 3 | beruni
# City not found. Skipping...
# Processing Record 46 of Set 3 | makakilo city
# Processing Record 47 of Set 3 | deputatskiy
# Processing Record 48 of Set 3 | geraldton
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 50 of Set 3 | humaita
# Processing Record 1 of Set 4 | coroieni
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | la ciotat
# Processing Record 4 of Set 4 | tessalit
# Processing Record 5 of Set 4 | baykit
# Processing Record 6 of Set 4 | beyneu
# Processing Record 7 of Set 4 | plainview
# Processing Record 8 of Set 4 | vila do maio
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | cabo rojo
# Processing Record 11 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 4 | finschhafen
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | griffith
# Processing Record 15 of Set 4 | plettenberg bay
# Processing Record 16 of Set 4 | yarmouth
# Processing Record 17 of Set 4 | fayaoue
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | nsanje
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | joshimath
# Processing Record 24 of Set 4 | jamestown
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | inuvik
# Processing Record 27 of Set 4 | hyeres
# Processing Record 28 of Set 4 | bredasdorp
# Processing Record 29 of Set 4 | fuerte olimpo
# Processing Record 30 of Set 4 | igarka
# Processing Record 31 of Set 4 | san patricio
# Processing Record 32 of Set 4 | itaueira
# Processing Record 33 of Set 4 | letterkenny
# Processing Record 34 of Set 4 | snasa
# Processing Record 35 of Set 4 | salym
# Processing Record 36 of Set 4 | parana
# Processing Record 37 of Set 4 | bara
# Processing Record 38 of Set 4 | chapais
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | sanary-sur-mer
# Processing Record 41 of Set 4 | santiago de cuba
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | ransang
# Processing Record 44 of Set 4 | never
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | victoria point
# Processing Record 49 of Set 4 | arkhangelsk
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | verkhoyansk
# Processing Record 2 of Set 5 | szprotawa
# Processing Record 3 of Set 5 | krasnyy oktyabr
# Processing Record 4 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 5 of Set 5 | kavieng
# Processing Record 6 of Set 5 | wewak
# Processing Record 7 of Set 5 | naifaru
# Processing Record 8 of Set 5 | takoradi
# Processing Record 9 of Set 5 | bantou
# Processing Record 10 of Set 5 | khorixas
# Processing Record 11 of Set 5 | barra do garcas
# Processing Record 12 of Set 5 | mineral wells
# Processing Record 13 of Set 5 | san jose
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | skjervoy
# Processing Record 16 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 5 | barrow
# Processing Record 18 of Set 5 | port hardy
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | waddan
# Processing Record 21 of Set 5 | burnie
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | kovur
# Processing Record 24 of Set 5 | kalmunai
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | ridgecrest
# Processing Record 27 of Set 5 | martapura
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | nanakuli
# Processing Record 30 of Set 5 | viedma
# Processing Record 31 of Set 5 | vostok
# Processing Record 32 of Set 5 | saint george
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | veraval
# Processing Record 35 of Set 5 | luwuk
# Processing Record 36 of Set 5 | port lincoln
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | jagdalpur
# Processing Record 39 of Set 5 | hakkari
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | kavaratti
# Processing Record 42 of Set 5 | kawambwa
# Processing Record 43 of Set 5 | acajutla
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | kirksville
# Processing Record 46 of Set 5 | broome
# Processing Record 47 of Set 5 | kampot
# Processing Record 48 of Set 5 | beloha
# Processing Record 49 of Set 5 | saskylakh
# Processing Record 50 of Set 5 | altamira
# Processing Record 1 of Set 6 | villazon
# Processing Record 2 of Set 6 | bela vista
# Processing Record 3 of Set 6 | cherskiy
# Processing Record 4 of Set 6 | eureka
# Processing Record 5 of Set 6 | sao francisco de paula
# Processing Record 6 of Set 6 | palmer
# Processing Record 7 of Set 6 | altyn-topkan
# Processing Record 8 of Set 6 | gore
# Processing Record 9 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 6 | wukari
# Processing Record 11 of Set 6 | cidreira
# Processing Record 12 of Set 6 | yellowknife
# Processing Record 13 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 6 | sioux lookout
# Processing Record 15 of Set 6 | north bend
# Processing Record 16 of Set 6 | tautira
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | pontes e lacerda
# Processing Record 19 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 6 | laguna
# Processing Record 21 of Set 6 | milkovo
# Processing Record 22 of Set 6 | ashland
# Processing Record 23 of Set 6 | maragogi
# Processing Record 24 of Set 6 | acapulco
# Processing Record 25 of Set 6 | asilah
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | asau
# Processing Record 28 of Set 6 | faanui
# Processing Record 29 of Set 6 | oria
# Processing Record 30 of Set 6 | holme
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | tuatapere
# Processing Record 33 of Set 6 | yarim
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | palana
# Processing Record 36 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 6 | tasiilaq
# Processing Record 38 of Set 6 | saumur
# Processing Record 39 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 6 | sicuani
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | natchez
# Processing Record 43 of Set 6 | puro
# Processing Record 44 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 6 | horadiz
# Processing Record 46 of Set 6 | the valley
# Processing Record 47 of Set 6 | teya
# Processing Record 48 of Set 6 | tyrma
# Processing Record 49 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | saint charles
# Processing Record 1 of Set 7 | ekibastuz
# Processing Record 2 of Set 7 | buraydah
# Processing Record 3 of Set 7 | kimbe
# Processing Record 4 of Set 7 | okmulgee
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | iralaya
# Processing Record 7 of Set 7 | mopipi
# Processing Record 8 of Set 7 | morehead
# Processing Record 9 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 7 | koumac
# Processing Record 12 of Set 7 | port dickson
# Processing Record 13 of Set 7 | heihe
# Processing Record 14 of Set 7 | kargasok
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | nuuk
# Processing Record 17 of Set 7 | cody
# Processing Record 18 of Set 7 | asfi
# Processing Record 19 of Set 7 | karratha
# Processing Record 20 of Set 7 | hirara
# Processing Record 21 of Set 7 | zhob
# Processing Record 22 of Set 7 | kirkwall
# Processing Record 23 of Set 7 | gondanglegi
# Processing Record 24 of Set 7 | manzhouli
# Processing Record 25 of Set 7 | nadym
# Processing Record 26 of Set 7 | iznik
# Processing Record 27 of Set 7 | beian
# Processing Record 28 of Set 7 | mao
# Processing Record 29 of Set 7 | vaitape
# Processing Record 30 of Set 7 | longyearbyen
# Processing Record 31 of Set 7 | galveston
# Processing Record 32 of Set 7 | sorong
# Processing Record 33 of Set 7 | san andres
# Processing Record 34 of Set 7 | champerico
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | bud
# Processing Record 37 of Set 7 | saint anthony
# Processing Record 38 of Set 7 | vila
# Processing Record 39 of Set 7 | basoko
# Processing Record 40 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 7 | atar
# Processing Record 42 of Set 7 | rabaul
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | eyl
# Processing Record 45 of Set 7 | sol-iletsk
# Processing Record 46 of Set 7 | grindavik
# Processing Record 47 of Set 7 | guarapari
# Processing Record 48 of Set 7 | phan thiet
# Processing Record 49 of Set 7 | ribeira grande
# Processing Record 50 of Set 7 | alice springs
# Processing Record 1 of Set 8 | jalu
# Processing Record 2 of Set 8 | ulladulla
# Processing Record 3 of Set 8 | bintulu
# Processing Record 4 of Set 8 | port moresby
# Processing Record 5 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 6 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 8 | visby
# Processing Record 8 of Set 8 | voznesenye
# Processing Record 9 of Set 8 | hagere selam
# Processing Record 10 of Set 8 | hamilton
# Processing Record 11 of Set 8 | ratnagiri
# Processing Record 12 of Set 8 | yulin
# Processing Record 13 of Set 8 | cap-aux-meules
# Processing Record 14 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 15 of Set 8 | poum
# Processing Record 16 of Set 8 | elesbao veloso
# Processing Record 17 of Set 8 | kholmy
# Processing Record 18 of Set 8 | badou
# Processing Record 19 of Set 8 | kheralu
# Processing Record 20 of Set 8 | saint-paul
# Processing Record 21 of Set 8 | filadelfia
# Processing Record 22 of Set 8 | umba
# Processing Record 23 of Set 8 | leirvik
# Processing Record 24 of Set 8 | krasnoselkup
# Processing Record 25 of Set 8 | sayhat
# Processing Record 26 of Set 8 | kiunga
# Processing Record 27 of Set 8 | honiara
# Processing Record 28 of Set 8 | vardo
# Processing Record 29 of Set 8 | ginda
# Processing Record 30 of Set 8 | norman wells
# Processing Record 31 of Set 8 | masterton
# Processing Record 32 of Set 8 | severo-kurilsk
# Processing Record 33 of Set 8 | sandur
# Processing Record 34 of Set 8 | pokhara
# Processing Record 35 of Set 8 | tezu
# Processing Record 36 of Set 8 | vanimo
# Processing Record 37 of Set 8 | dobson
# Processing Record 38 of Set 8 | minyar
# Processing Record 39 of Set 8 | imbituba
# Processing Record 40 of Set 8 | maldonado
# Processing Record 41 of Set 8 | point pleasant
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 44 of Set 8 | aljezur
# Processing Record 45 of Set 8 | hami
# Processing Record 46 of Set 8 | chokurdakh
# Processing Record 47 of Set 8 | samarai
# Processing Record 48 of Set 8 | ruteng
# Processing Record 49 of Set 8 | grand gaube
# Processing Record 50 of Set 8 | shelburne
# Processing Record 1 of Set 9 | gadung
# Processing Record 2 of Set 9 | bereda
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | suntar
# Processing Record 5 of Set 9 | ulaanbaatar
# Processing Record 6 of Set 9 | markala
# Processing Record 7 of Set 9 | harper
# Processing Record 8 of Set 9 | rocha
# Processing Record 9 of Set 9 | wazzan
# City not found. Skipping...
# Processing Record 10 of Set 9 | burica
# City not found. Skipping...
# Processing Record 11 of Set 9 | ossora
# Processing Record 12 of Set 9 | nuevitas
# Processing Record 13 of Set 9 | xingcheng
# Processing Record 14 of Set 9 | bow island
# Processing Record 15 of Set 9 | cootamundra
# Processing Record 16 of Set 9 | siocon
# Processing Record 17 of Set 9 | muscatine
# Processing Record 18 of Set 9 | fort nelson
# Processing Record 19 of Set 9 | dwarka
# Processing Record 20 of Set 9 | teguldet
# Processing Record 21 of Set 9 | santa ana
# Processing Record 22 of Set 9 | eidfjord
# Processing Record 23 of Set 9 | kazanskaya
# Processing Record 24 of Set 9 | montepuez
# Processing Record 25 of Set 9 | kitui
# Processing Record 26 of Set 9 | saint-francois
# Processing Record 27 of Set 9 | igrim
# Processing Record 28 of Set 9 | rockland
# Processing Record 29 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 9 | ye
# City not found. Skipping...
# Processing Record 31 of Set 9 | baoqing
# Processing Record 32 of Set 9 | staryy nadym
# Processing Record 33 of Set 9 | talaya
# Processing Record 34 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 35 of Set 9 | hambantota
# Processing Record 36 of Set 9 | dubai
# Processing Record 37 of Set 9 | sinnamary
# Processing Record 38 of Set 9 | maumere
# Processing Record 39 of Set 9 | lerwick
# Processing Record 40 of Set 9 | komsomolskiy
# Processing Record 41 of Set 9 | alihe
# Processing Record 42 of Set 9 | ouadda
# Processing Record 43 of Set 9 | russell
# Processing Record 44 of Set 9 | yenagoa
# Processing Record 45 of Set 9 | truckee
# Processing Record 46 of Set 9 | muros
# Processing Record 47 of Set 9 | matara
# Processing Record 48 of Set 9 | sokoni
# Processing Record 49 of Set 9 | achalpur
# Processing Record 50 of Set 9 | sangar
# Processing Record 1 of Set 10 | sibi
# Processing Record 2 of Set 10 | abu samrah
# Processing Record 3 of Set 10 | leningradskiy
# Processing Record 4 of Set 10 | murray bridge
# Processing Record 5 of Set 10 | flin flon
# Processing Record 6 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | guerrero negro
# Processing Record 9 of Set 10 | sumbe
# Processing Record 10 of Set 10 | mecca
# Processing Record 11 of Set 10 | kortkeros
# Processing Record 12 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 13 of Set 10 | ningan
# City not found. Skipping...
# Processing Record 14 of Set 10 | siuna
# Processing Record 15 of Set 10 | agadez
# Processing Record 16 of Set 10 | tateyama
# Processing Record 17 of Set 10 | gravdal
# Processing Record 18 of Set 10 | bonoua
# Processing Record 19 of Set 10 | aguas verdes
# Processing Record 20 of Set 10 | mulege
# Processing Record 21 of Set 10 | ngozi
# Processing Record 22 of Set 10 | isangel
# Processing Record 23 of Set 10 | oistins
# Processing Record 24 of Set 10 | verkhnevilyuysk
# Processing Record 25 of Set 10 | oriximina
# Processing Record 26 of Set 10 | plaster rock
# Processing Record 27 of Set 10 | havelock
# Processing Record 28 of Set 10 | waingapu
# Processing Record 29 of Set 10 | dores do indaia
# Processing Record 30 of Set 10 | zhigansk
# Processing Record 31 of Set 10 | kaiyuan
# Processing Record 32 of Set 10 | kurchum
# Processing Record 33 of Set 10 | taoudenni
# Processing Record 34 of Set 10 | hanzhong
# Processing Record 35 of Set 10 | svetlogorsk
# Processing Record 36 of Set 10 | faya
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 10 | kulachi
# Processing Record 40 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 41 of Set 10 | chicama
# Processing Record 42 of Set 10 | hai duong
# Processing Record 43 of Set 10 | gazojak
# Processing Record 44 of Set 10 | bulaevo
# Processing Record 45 of Set 10 | raudeberg
# Processing Record 46 of Set 10 | rock sound
# Processing Record 47 of Set 10 | ati
# Processing Record 48 of Set 10 | kamenka
# Processing Record 49 of Set 10 | becerril
# Processing Record 50 of Set 10 | abu dhabi
# Processing Record 1 of Set 11 | vallenar
# Processing Record 2 of Set 11 | praya
# Processing Record 3 of Set 11 | boulder
# Processing Record 4 of Set 11 | piojo
# Processing Record 5 of Set 11 | zaykovo
# Processing Record 6 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | kloulklubed
# Processing Record 9 of Set 11 | hoquiam
# Processing Record 10 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 11 of Set 11 | nelson bay
# Processing Record 12 of Set 11 | amapa
# Processing Record 13 of Set 11 | coihaique
# Processing Record 14 of Set 11 | tres picos
# Processing Record 15 of Set 11 | mbandaka
# Processing Record 16 of Set 11 | jambi
# Processing Record 17 of Set 11 | duluth
# Processing Record 18 of Set 11 | toccoa
# Processing Record 19 of Set 11 | rumonge
# Processing Record 20 of Set 11 | santa isabel
# Processing Record 21 of Set 11 | yamada
# Processing Record 22 of Set 11 | wiefelstede
# Processing Record 23 of Set 11 | henties bay
# Processing Record 24 of Set 11 | dingle
# Processing Record 25 of Set 11 | druzhnaya gorka
# Processing Record 26 of Set 11 | ngunguru
# Processing Record 27 of Set 11 | bonthe
# Processing Record 28 of Set 11 | oktyabrskoye
# Processing Record 29 of Set 11 | rosarito
# Processing Record 30 of Set 11 | dunmore east
# Processing Record 31 of Set 11 | bom jardim
# Processing Record 32 of Set 11 | roald
# Processing Record 33 of Set 11 | vigrestad
# Processing Record 34 of Set 11 | kodinsk
# Processing Record 35 of Set 11 | zhoucheng
# Processing Record 36 of Set 11 | mahanje
# Processing Record 37 of Set 11 | yenisehir
# Processing Record 38 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 39 of Set 11 | lata
# Processing Record 40 of Set 11 | nome
# Processing Record 41 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 11 | shirwal
# Processing Record 43 of Set 11 | mehamn
# Processing Record 44 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 11 | matay
# Processing Record 46 of Set 11 | marrakesh
# Processing Record 47 of Set 11 | bad durrenberg
# Processing Record 48 of Set 11 | juneau
# Processing Record 49 of Set 11 | ha giang
# Processing Record 50 of Set 11 | nabire
# Processing Record 1 of Set 12 | maraa
# Processing Record 2 of Set 12 | serov
# Processing Record 3 of Set 12 | slobodskoy
# Processing Record 4 of Set 12 | lermontovka
# Processing Record 5 of Set 12 | norton shores
# Processing Record 6 of Set 12 | fairbanks
# Processing Record 7 of Set 12 | rafaela
# Processing Record 8 of Set 12 | anadyr
# Processing Record 9 of Set 12 | cornwall
# Processing Record 10 of Set 12 | cananeia
# Processing Record 11 of Set 12 | ranot
# Processing Record 12 of Set 12 | sorland
# Processing Record 13 of Set 12 | panguna
# Processing Record 14 of Set 12 | saint-leu
# Processing Record 15 of Set 12 | sabha
# Processing Record 16 of Set 12 | giehun
# Processing Record 17 of Set 12 | gogrial
# Processing Record 18 of Set 12 | sao joao da barra
# Processing Record 19 of Set 12 | kolondieba
# Processing Record 20 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 22 of Set 12 | kumhari
# Processing Record 23 of Set 12 | takaka
# Processing Record 24 of Set 12 | alyangula
# Processing Record 25 of Set 12 | duz
# City not found. Skipping...
# Processing Record 26 of Set 12 | solnechnyy
# Processing Record 27 of Set 12 | assare
# Processing Record 28 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 29 of Set 12 | fare
# Processing Record 30 of Set 12 | la macarena
# Processing Record 31 of Set 12 | chimore
# Processing Record 32 of Set 12 | esso
# Processing Record 33 of Set 12 | kholtoson
# Processing Record 34 of Set 12 | riyadh
# Processing Record 35 of Set 12 | tanga
# Processing Record 36 of Set 12 | strabychovo
# Processing Record 37 of Set 12 | les cayes
# Processing Record 38 of Set 12 | liverpool
# Processing Record 39 of Set 12 | along
# Processing Record 40 of Set 12 | zhuhai
# Processing Record 41 of Set 12 | pravda
# Processing Record 42 of Set 12 | parral
# Processing Record 43 of Set 12 | balikpapan
# Processing Record 44 of Set 12 | pacific grove
# Processing Record 45 of Set 12 | papara
# Processing Record 46 of Set 12 | ugoofaaru
# Processing Record 47 of Set 12 | masuguru
# Processing Record 48 of Set 12 | rabo de peixe
# Processing Record 49 of Set 12 | dzhebariki-khaya
# Processing Record 50 of Set 12 | fairfield
# Processing Record 1 of Set 13 | morant bay
# Processing Record 2 of Set 13 | pahrump
# Processing Record 3 of Set 13 | auki
# Processing Record 4 of Set 13 | san quintin
# Processing Record 5 of Set 13 | doka
# Processing Record 6 of Set 13 | kushiro
# Processing Record 7 of Set 13 | talcahuano
# Processing Record 8 of Set 13 | road town
# Processing Record 9 of Set 13 | nayoro
# Processing Record 10 of Set 13 | trapani
# Processing Record 11 of Set 13 | novyy urengoy
# Processing Record 12 of Set 13 | moussoro
# Processing Record 13 of Set 13 | monroe
# Processing Record 14 of Set 13 | acari
# Processing Record 15 of Set 13 | bulgan
# Processing Record 16 of Set 13 | carballo
# Processing Record 17 of Set 13 | springbok
# Processing Record 18 of Set 13 | ouesso
# Processing Record 19 of Set 13 | westport
# Processing Record 20 of Set 13 | sinegorye
# Processing Record 21 of Set 13 | nishihara
# Processing Record 22 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 13 | atherton
# Processing Record 24 of Set 13 | kenai
# Processing Record 25 of Set 13 | atambua
# Processing Record 26 of Set 13 | reconquista
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | sisimiut
# Processing Record 29 of Set 13 | hanting
# Processing Record 30 of Set 13 | kungurtug
# Processing Record 31 of Set 13 | cap malheureux
# Processing Record 32 of Set 13 | camacha
# Processing Record 33 of Set 13 | codrington
# Processing Record 34 of Set 13 | apastovo
# Processing Record 35 of Set 13 | uspenka
# Processing Record 36 of Set 13 | baghdad
# Processing Record 37 of Set 13 | mikhaylovka
# Processing Record 38 of Set 13 | yanam
# Processing Record 39 of Set 13 | kruisfontein
# Processing Record 40 of Set 13 | sabang
# Processing Record 41 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 13 | tual
# Processing Record 43 of Set 13 | armidale
# Processing Record 44 of Set 13 | yeppoon
# Processing Record 45 of Set 13 | maryville
# Processing Record 46 of Set 13 | nemuro
# Processing Record 47 of Set 13 | bandar penggaram
# City not found. Skipping...
# Processing Record 48 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 13 | kiama
# Processing Record 50 of Set 13 | zambezi
# Processing Record 1 of Set 14 | ballina
# Processing Record 2 of Set 14 | puerto carreno
# Processing Record 3 of Set 14 | dortyol
# Processing Record 4 of Set 14 | kailua
# Processing Record 5 of Set 14 | balykshi
# Processing Record 6 of Set 14 | visnes
# Processing Record 7 of Set 14 | at-bashi
# Processing Record 8 of Set 14 | say
# Processing Record 9 of Set 14 | coquimbo
# Processing Record 10 of Set 14 | scarborough
# Processing Record 11 of Set 14 | inverness
# Processing Record 12 of Set 14 | inongo
# Processing Record 13 of Set 14 | koutiala
# Processing Record 14 of Set 14 | kropotkin
# Processing Record 15 of Set 14 | coahuayana
# Processing Record 16 of Set 14 | rio pomba
# Processing Record 17 of Set 14 | udachnyy
# Processing Record 18 of Set 14 | kaeo
# Processing Record 19 of Set 14 | severomuysk
# Processing Record 20 of Set 14 | linxi
# Processing Record 21 of Set 14 | egvekinot
# Processing Record 22 of Set 14 | port macquarie
# Processing Record 23 of Set 14 | tortoli
# Processing Record 24 of Set 14 | lebyazhye
# Processing Record 25 of Set 14 | anloga
# Processing Record 26 of Set 14 | trang
# Processing Record 27 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 14 | tera
# Processing Record 29 of Set 14 | hobyo
# Processing Record 30 of Set 14 | dabhol
# Processing Record 31 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 14 | lumeje
# Processing Record 33 of Set 14 | khandyga
# Processing Record 34 of Set 14 | fort collins
# Processing Record 35 of Set 14 | mount isa
# Processing Record 36 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 14 | tarko-sale
# Processing Record 38 of Set 14 | tarauaca
# Processing Record 39 of Set 14 | salalah
# Processing Record 40 of Set 14 | orlik
# Processing Record 41 of Set 14 | boa vista
# Processing Record 42 of Set 14 | kuroiso
# Processing Record 43 of Set 14 | port hueneme
# Processing Record 44 of Set 14 | kudahuvadhoo
# Processing Record 45 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 46 of Set 14 | hualmay
# Processing Record 47 of Set 14 | sultanpur
# Processing Record 48 of Set 14 | san rafael
# Processing Record 49 of Set 14 | atsiki
# City not found. Skipping...
# Processing Record 50 of Set 14 | villablino
# Processing Record 1 of Set 15 | chapleau
# Processing Record 2 of Set 15 | kidal
# Processing Record 3 of Set 15 | nizhneangarsk
# Processing Record 4 of Set 15 | darnah
# Processing Record 5 of Set 15 | sulangan
# Processing Record 6 of Set 15 | vila velha
# Processing Record 7 of Set 15 | banda aceh
# Processing Record 8 of Set 15 | mogadishu
# Processing Record 9 of Set 15 | klamath falls
# Processing Record 10 of Set 15 | upata
# Processing Record 11 of Set 15 | kutum
# Processing Record 12 of Set 15 | belaya gora
# Processing Record 13 of Set 15 | luang prabang
# Processing Record 14 of Set 15 | ingham
# Processing Record 15 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 15 | porto-vecchio
# Processing Record 17 of Set 15 | paragominas
# Processing Record 18 of Set 15 | vila franca do campo
# Processing Record 19 of Set 15 | agara
# Processing Record 20 of Set 15 | bafq
# Processing Record 21 of Set 15 | itoman
# Processing Record 22 of Set 15 | san carlos de bariloche
# Processing Record 23 of Set 15 | la ronge
# Processing Record 24 of Set 15 | misasi
# Processing Record 25 of Set 15 | burns lake
# Processing Record 26 of Set 15 | bage
# Processing Record 27 of Set 15 | farafangana
# Processing Record 28 of Set 15 | huron
# Processing Record 29 of Set 15 | monaragala
# Processing Record 30 of Set 15 | ekhabi
# Processing Record 31 of Set 15 | rawson
# Processing Record 32 of Set 15 | algiers
# Processing Record 33 of Set 15 | namwala
# Processing Record 34 of Set 15 | namatanai
# Processing Record 35 of Set 15 | coari
# Processing Record 36 of Set 15 | pedernales
# Processing Record 37 of Set 15 | verkhnyaya inta
# Processing Record 38 of Set 15 | eucaliptus
# Processing Record 39 of Set 15 | meulaboh
# Processing Record 40 of Set 15 | srandakan
# Processing Record 41 of Set 15 | adrar
# Processing Record 42 of Set 15 | olafsvik
# Processing Record 43 of Set 15 | jawhar
# Processing Record 44 of Set 15 | tura
# Processing Record 45 of Set 15 | hurghada
# Processing Record 46 of Set 15 | barawe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Hermanus -34.4187   19.2345     59.81        81          35       11.90
# 1      Hobart -42.8794  147.3294     72.27        70          75        1.99
# 2        Chuy -33.6971  -53.4616     63.88        79           0        4.76
# 3    Bengkulu  -3.8004  102.2655     82.81        68         100        2.46
# 4   Busselton -33.6500  115.3333     96.04        42          96        6.22
# 5    Katsuura  35.1333  140.3000     44.71        94         100       10.98
# 6   Kununurra -15.7667  128.7333     91.38        62          40       12.66
# 7  Georgetown   5.4112  100.3354     89.53        77          20        3.00
# 8   Cape Town -33.9258   18.4232     64.35        75           4        4.00
# 9     Mataura -46.1927  168.8643     66.47        24          75        7.23
#
#   Country                 Date Current Description
# 0      ZA  2022-01-29 03:34:47    scattered clouds
# 1      AU  2022-01-29 03:30:03       broken clouds
# 2      UY  2022-01-29 03:34:48           clear sky
# 3      ID  2022-01-29 03:34:48       moderate rain
# 4      AU  2022-01-29 03:34:12     overcast clouds
# 5      JP  2022-01-29 03:31:28     overcast clouds
# 6      AU  2022-01-29 03:34:13    scattered clouds
# 7      MY  2022-01-29 03:33:04                haze
# 8      ZA  2022-01-29 03:30:19           clear sky
# 9      NZ  2022-01-29 03:34:49       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus      ZA -34.4187   19.2345     59.81        81          35
# 1       Hobart      AU -42.8794  147.3294     72.27        70          75
# 2         Chuy      UY -33.6971  -53.4616     63.88        79           0
# 3     Bengkulu      ID  -3.8004  102.2655     82.81        68         100
# 4    Busselton      AU -33.6500  115.3333     96.04        42          96
# ..         ...     ...      ...       ...       ...       ...         ...
# 678      Adrar      MR  20.5022  -10.0711     70.68        12         100
# 679   Olafsvik      IS  64.8945  -23.7142     26.46        63          23
# 680     Jawhar      SO   2.7809   45.5005     71.94        76          99
# 681       Tura      IN  25.5198   90.2201     65.91        35           0
# 682   Hurghada      EG  27.2574   33.8129     51.84        54           0
#
#      Wind Speed Current Description
# 0         11.90    scattered clouds
# 1          1.99       broken clouds
# 2          4.76           clear sky
# 3          2.46       moderate rain
# 4          6.22     overcast clouds
# ..          ...                 ...
# 678        4.70     overcast clouds
# 679       16.33          few clouds
# 680       13.33     overcast clouds
# 681        2.68           clear sky
# 682       12.66           clear sky
#
# [683 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
